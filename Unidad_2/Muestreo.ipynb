# %%
import pandas as pd
import numpy as np
import random

import os

# %%
filename="bigdatita/Bicicletas/data.csv"
df=pd.read_csv("bigdatita/Bicicletas/data.csv",nrows=300000)
df.head()
# Out:
#    trip_id  year  month  week  day  hour    usertype  gender  \
# 0  2355134  2014      6    27    0    23  Subscriber    Male
# 1  2355133  2014      6    27    0    23  Subscriber    Male
# 2  2355130  2014      6    27    0    23  Subscriber    Male
# 3  2355129  2014      6    27    0    23  Subscriber  Female
# 4  2355128  2014      6    27    0    23  Subscriber  Female
#
#              starttime             stoptime  ...  from_station_id  \
# 0  2014-06-30 23:57:00  2014-07-01 00:07:00  ...              131
# 1  2014-06-30 23:56:00  2014-07-01 00:00:00  ...              282
# 2  2014-06-30 23:33:00  2014-06-30 23:35:00  ...              327
# 3  2014-06-30 23:26:00  2014-07-01 00:24:00  ...              134
# 4  2014-06-30 23:16:00  2014-06-30 23:26:00  ...              320
#
#              from_station_name latitude_start  longitude_start  \
# 0    Lincoln Ave & Belmont Ave      41.939365       -87.668385
# 1      Halsted St & Maxwell St      41.864580       -87.646930
# ...

# %%
df.to_csv("bigdatita/Bicicletas/PrimerasFilas.csv",index=False)

# %%
n=9495236-1
s = 10000 #desired sample size
skip = sorted(random.sample(range(1,n+1),n-s) ) #the 0-indexed header will not be included in the skip list
df = pd.read_csv(filename, skiprows=skip)

# %%
df.to_csv("bigdatita/Bicicletas/muestra.csv",index=False)

# %%
pd.read_csv("bigdatita/Bicicletas/muestra.csv")
# Out:
#        trip_id  year  month  week  day  hour    usertype  gender  \
# 0      2351275  2014      6    27    0    16  Subscriber  Female
# 1      2350992  2014      6    27    0    16  Subscriber    Male
# 2      2350632  2014      6    27    0    16  Subscriber    Male
# 3      2348720  2014      6    27    0    13  Subscriber    Male
# 4      2348148  2014      6    27    0    12  Subscriber    Male
# ...        ...   ...    ...   ...  ...   ...         ...     ...
# 9995  16737337  2017     10    39    6    11  Subscriber    Male
# 9996  16737035  2017     10    39    6    11  Subscriber  Female
# 9997  16736342  2017     10    39    6    10  Subscriber  Female
# 9998  16735727  2017     10    39    6    10  Subscriber    Male
# 9999  16734344  2017     10    39    6     2  Subscriber    Male
#
#                 starttime             stoptime  ...  from_station_id  \
# 0     2014-06-30 16:41:00  2014-06-30 17:00:00  ...              337
# ...
